# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from IPython.display import display, Latex

import scienceplots
plt.style.use(['science', 'notebook', 'grid']) 
plt.rcParams['figure.figsize'] = [8, 8]

# %%
T_collapse = 1.1107207345395915
display(Latex(f'Expected T_collapse = ${T_collapse}$ iu'))
# Out:
# Expected T_collapse = $1.1107207345395915$ iu

# %% [markdown]
# # Collecting Data

# %% [markdown]
# ### N = 100

# %%
time_100_array = np.array([7.66, 7.69, 7.89, 6.02, 6.26, 8.30, 13.93, 11.81, 10.55, 7.42])
time_100 = np.array([np.mean(time_100_array), np.std(time_100_array, ddof=1)/np.sqrt(len(time_100_array))])
display(Latex(f'Time = ${time_100[0]:.2f} \pm {time_100[1]:.2f}$ s'))
display(Latex(f'Relative std of the mean = ${time_100[1]/time_100[0]:.3f}$'))
# Out:
# Time = $8.75 \pm 0.80$ s
# Relative std of the mean = $0.092$

# %%
tcoll_100_array = np.array([1.164038391972886, 1.248012765695003, 1.296018455181368, 1.173007284438172, 1.19702650832861, 1.209008823535554, 1.317038999655635, 1.200000913316228, 1.140025173153413, 1.275059339079787])
tcoll_100 = np.array([np.mean(tcoll_100_array), np.std(tcoll_100_array, ddof=1)/np.sqrt(len(tcoll_100_array))])
display(Latex(f'T_collapse = ${tcoll_100[0]:.3f} \pm {tcoll_100[1]:.3f}$ iu'))
display(Latex(f'Relative std of the mean = ${tcoll_100[1]/tcoll_100[0]:.3f}$'))
# Out:
# T_collapse = $1.222 \pm 0.019$ iu
# Relative std of the mean = $0.015$

# %% [markdown]
# ### N = 125

# %%
time_125_array = np.array([11.86, 17.34, 13.42, 14.01, 14.87, 10.77, 12.49, 11.51, 11.24, 16.93])
time_125 = np.array([np.mean(time_125_array), np.std(time_125_array, ddof=1)/np.sqrt(len(time_125_array))])
display(Latex(f'Time = ${time_125[0]:.2f} \pm {time_125[1]:.2f}$ s'))
display(Latex(f'Relative std of the mean = ${time_125[1]/time_125[0]:.3f}$'))
# Out:
# Time = $13.44 \pm 0.74$ s
# Relative std of the mean = $0.055$

# %%
tcoll_125_array = np.array([1.30801859150107, 1.170040062564309, 1.212011365948065, 1.218000375535129, 1.218017995866705, 1.212001871939137, 1.266023351891629, 1.176039418910517, 1.179061880786737, 1.251007912062903])
tcoll_125 = np.array([np.mean(tcoll_125_array), np.std(tcoll_125_array, ddof=1)/np.sqrt(len(tcoll_125_array))])
display(Latex(f'T_collapse = ${tcoll_125[0]:.3f} \pm {tcoll_125[1]:.3f}$ iu'))
display(Latex(f'Relative std of the mean = ${tcoll_125[1]/tcoll_125[0]:.3f}$'))
# Out:
# T_collapse = $1.221 \pm 0.014$ iu
# Relative std of the mean = $0.011$

# %% [markdown]
# ### N = 150

# %%
time_150_array = np.array([32.23, 21.50, 23.91, 22.28, 18.48, 22.14, 19.10, 34.72, 20.61, 20.29])
time_150 = np.array([np.mean(time_150_array), np.std(time_150_array, ddof=1)/np.sqrt(len(time_150_array))])
display(Latex(f'Time = ${time_150[0]:.1f} \pm {time_150[1]:.1f}$ s'))
display(Latex(f'Relative std of the mean = ${time_150[1]/time_150[0]:.3f}$'))
# Out:
# Time = $23.5 \pm 1.7$ s
# Relative std of the mean = $0.074$

# %%
tcoll_150_array = np.array([1.245000828156935, 1.116011929959163, 1.179007738456106, 1.233005408969266, 1.2060263161494, 1.281027022351986, 1.239023760541812, 1.209015011653224, 1.185032039468261, 1.206016697726111])
tcoll_150 = np.array([np.mean(tcoll_150_array), np.std(tcoll_150_array, ddof=1)/np.sqrt(len(tcoll_150_array))])
display(Latex(f'T_collapse = ${tcoll_150[0]:.3f} \pm {tcoll_150[1]:.3f}$ iu'))
display(Latex(f'Relative std of the mean = ${tcoll_150[1]/tcoll_150[0]:.3f}$'))
# Out:
# T_collapse = $1.210 \pm 0.014$ iu
# Relative std of the mean = $0.012$

# %% [markdown]
# ### N = 175

# %%
time_175_array = np.array([36.16, 28.30, 36.30, 31.45, 40.02, 50.39, 28.69, 27.52, 35.85, 31.50])
time_175 = np.array([np.mean(time_175_array), np.std(time_175_array, ddof=1)/np.sqrt(len(time_175_array))])
display(Latex(f'Time = ${time_175[0]:.1f} \pm {time_175[1]:.1f}$ s'))
display(Latex(f'Relative std of the mean = ${time_175[1]/time_175[0]:.3f}$'))
# Out:
# Time = $34.6 \pm 2.2$ s
# Relative std of the mean = $0.063$

# %%
tcoll_175_array = np.array([1.197007398973509, 1.191016126890831, 1.21202212763358, 1.197003447921364, 1.164028154109435, 1.203011934334089, 1.230013166946165, 1.218010918678726, 1.1550142232516, 1.20901599768009])
tcoll_175 = np.array([np.mean(tcoll_175_array), np.std(tcoll_175_array, ddof=1)/np.sqrt(len(tcoll_175_array))])
display(Latex(f'T_collapse = ${tcoll_175[0]:.3f} \pm {tcoll_175[1]:.3f}$ iu'))
display(Latex(f'Relative std of the mean = ${tcoll_175[1]/tcoll_175[0]:.3f}$'))
# Out:
# T_collapse = $1.198 \pm 0.007$ iu
# Relative std of the mean = $0.006$

# %% [markdown]
# ### N = 200

# %%
time_200_array = np.array([41.79, 42.79, 40.82, 42.31, 38.21, 55.61, 41.15, 58.75, 39.76, 46.42])
time_200 = np.array([np.mean(time_200_array), np.std(time_200_array, ddof=1)/np.sqrt(len(time_200_array))])
display(Latex(f'Time = ${time_200[0]:.1f} \pm {time_200[1]:.1f}$ s'))
display(Latex(f'Relative std of the mean = ${time_200[1]/time_200[0]:.3f}$'))
# Out:
# Time = $44.8 \pm 2.2$ s
# Relative std of the mean = $0.049$

# %%
tcoll_200_array = np.array([1.179007374814726, 1.152007862519536, 1.18501753940326, 1.203004018359262, 1.245020894363307, 1.188009548832047, 1.173018999897253, 1.206003123197469, 1.203007470469867, 1.227015657447289])
tcoll_200 = np.array([np.mean(tcoll_200_array), np.std(tcoll_200_array, ddof=1)/np.sqrt(len(tcoll_200_array))])
display(Latex(f'T_collapse = ${tcoll_200[0]:.3f} \pm {tcoll_200[1]:.3f}$ iu'))
display(Latex(f'Relative std of the mean = ${tcoll_200[1]/tcoll_200[0]:.3f}$'))
# Out:
# T_collapse = $1.196 \pm 0.008$ iu
# Relative std of the mean = $0.007$

# %% [markdown]
# ### N = 225

# %%
time_225_array = np.array([73.13, 65.66, 60.39, 91.36, 61.00, 73.84, 54.20, 85.90, 58.05, 60.37])
time_225 = np.array([np.mean(time_225_array), np.std(time_225_array, ddof=1)/np.sqrt(len(time_225_array))])
display(Latex(f'Time = ${time_225[0]:.1f} \pm {time_225[1]:.1f}$ s'))
display(Latex(f'Relative std of the mean = ${time_225[1]/time_225[0]:.3f}$'))
# Out:
# Time = $68.4 \pm 3.9$ s
# Relative std of the mean = $0.057$

# %%
tcoll_225_array = np.array([1.161004965591528, 1.16402279750443, 1.197003602896969, 1.242003129042074, 1.191013138243724, 1.230014034793951, 1.191013159466367, 1.182029493410877, 1.191001398926296, 1.218001828098046])
tcoll_225 = np.array([np.mean(tcoll_225_array), np.std(tcoll_225_array, ddof=1)/np.sqrt(len(tcoll_225_array))])
display(Latex(f'T_collapse = ${tcoll_225[0]:.3f} \pm {tcoll_225[1]:.3f}$ iu'))
display(Latex(f'Relative std of the mean = ${tcoll_225[1]/tcoll_225[0]:.3f}$'))
# Out:
# T_collapse = $1.197 \pm 0.008$ iu
# Relative std of the mean = $0.007$

# %% [markdown]
# ### N = 250

# %%
time_250_array = np.array([70.73, 67.69, 72.20, 84.66, 75.60, 85.18, 93.96, 100.15, 72.29, 104.08])
time_250 = np.array([np.mean(time_250_array), np.std(time_250_array, ddof=1)/np.sqrt(len(time_250_array))])
display(Latex(f'Time = ${time_250[0]:.1f} \pm {time_250[1]:.1f}$ s'))
display(Latex(f'Relative std of the mean = ${time_250[1]/time_250[0]:.3f}$'))
# Out:
# Time = $82.7 \pm 4.1$ s
# Relative std of the mean = $0.050$

# %%
tcoll_250_array = np.array([1.170008251633366, 1.218002819627366, 1.161042865230149, 1.242005927319641, 1.248025166843927, 1.185000642260483, 1.206004095592512, 1.215001772667581, 1.203000131326199, 1.200010357054839])
tcoll_250 = np.array([np.mean(tcoll_250_array), np.std(tcoll_250_array, ddof=1)/np.sqrt(len(tcoll_250_array))])
display(Latex(f'T_collapse = ${tcoll_250[0]:.3f} \pm {tcoll_250[1]:.3f}$ iu'))
display(Latex(f'Relative std of the mean = ${tcoll_250[1]/tcoll_250[0]:.3f}$'))
# Out:
# T_collapse = $1.205 \pm 0.009$ iu
# Relative std of the mean = $0.007$

# %% [markdown]
# ### N = 275

# %%
time_275_array = np.array([123.78, 84.46, 127.65, 100.32, 109.17, 101.37, 110.23, 143.04, 112.35, 117.33])
time_275 = np.array([np.mean(time_275_array), np.std(time_275_array, ddof=1)/np.sqrt(len(time_275_array))])
display(Latex(f'Time = ${time_275[0]:.1f} \pm {time_275[1]:.1f}$ s'))
display(Latex(f'Relative std of the mean = ${time_275[1]/time_275[0]:.3f}$'))
# Out:
# Time = $113.0 \pm 5.1$ s
# Relative std of the mean = $0.046$

# %%
tcoll_275_array = np.array([1.221011061226592, 1.116021131591504, 1.191008720669923, 1.16702117392986, 1.206002109810707, 1.209010895301184, 1.170011636444296, 1.140018995493114, 1.188026360526527, 1.215010725232449])
tcoll_275 = np.array([np.mean(tcoll_275_array), np.std(tcoll_275_array, ddof=1)/np.sqrt(len(tcoll_275_array))])
display(Latex(f'T_collapse = ${tcoll_275[0]:.3f} \pm {tcoll_275[1]:.3f}$ iu'))
display(Latex(f'Relative std of the mean = ${tcoll_275[1]/tcoll_275[0]:.3f}$'))
# Out:
# T_collapse = $1.182 \pm 0.011$ iu
# Relative std of the mean = $0.009$

# %% [markdown]
# ### N = 300

# %%
time_300_array = np.array([130.09, 140.93, 112.08, 195.89, 143.11, 203.95, 131.66, 160.00, 159.40, 210.76])
time_300 = np.array([np.mean(time_300_array), np.std(time_300_array, ddof=1)/np.sqrt(len(time_300_array))])
display(Latex(f'Time = ${time_300[0]:.1f} \pm {time_300[1]:.1f}$ s'))
display(Latex(f'Relative std of the mean = ${time_300[1]/time_300[0]:.3f}$'))
# Out:
# Time = $158.8 \pm 10.8$ s
# Relative std of the mean = $0.068$

# %%
tcoll_300_array = np.array([1.18800245185184, 1.185006719363246, 1.164000594676489, 1.194008884247658, 1.179006108261933, 1.161010890180009, 1.203010225491176, 1.158008640991329, 1.209019357721327, 1.164003906626008])
tcoll_300 = np.array([np.mean(tcoll_300_array), np.std(tcoll_300_array, ddof=1)/np.sqrt(len(tcoll_300_array))])
display(Latex(f'T_collapse = ${tcoll_300[0]:.3f} \pm {tcoll_300[1]:.3f}$ iu'))
display(Latex(f'Relative std of the mean = ${tcoll_300[1]/tcoll_300[0]:.3f}$'))
# Out:
# T_collapse = $1.181 \pm 0.006$ iu
# Relative std of the mean = $0.005$

# %% [markdown]
# # 1) Computational Time VS Number of Particles

# %%
Ns = np.array([100, 125, 150, 175, 200, 225, 250, 275, 300])
times = np.array([time_100, time_125, time_150, time_175, time_200, time_225, time_250, time_275, time_300]).T/time_100[0]

# %% [markdown]
# $f(N) = b N^\alpha + c$

# %%
def Powerlaw(x, alpha, C1, C2):
    return C1*x**alpha + C2

popt, pcov = curve_fit(Powerlaw, Ns, times[0], sigma=times[1], p0=(4., 1., 0.), absolute_sigma=True)
popt
# Out:
# array([2.92331856e+00, 9.41574719e-07, 3.20790808e-01])

# %%
x_dense = np.linspace(0, 350, 1000)

plt.errorbar(Ns, times[0], times[1], fmt='o', color='blue', ecolor='grey', capsize=4, capthick=2, label='Data')
plt.plot(x_dense, Powerlaw(x_dense, popt[0], popt[1], popt[2]), ls='--', color='deepskyblue', label=f'$\propto N^{{{popt[0]:.2f} \pm {np.sqrt(pcov[0,0]):.2f}}}$')
plt.title('Computational Time VS Number of Particles', fontsize=20)
plt.xlabel('Number of particles')
plt.ylabel('Computational time (in units of the smallest one)')
plt.legend(fontsize=20)

# %% [markdown]
# At first, we expected the computational time to be $\propto N^2$, since the algorithm has to compute $\frac{N(N-1)}{2}$ gravitational attractions at each time-step.
#
# However, the time-step is not a fixed quantity, but it is computed as: $\: d \times min\left(\left|\dfrac{x_{ij}}{v_{ij}}\right|, \sqrt{\dfrac{x_{ij}}{a_{ij}}}\right)$, where $d$ is chosen by the user.
#
# Since more particles in the same volume imply smaller distances between the particles, the time-step gets also smaller, and thus the computational time increases.

# %%
display(Latex(f'$N = 1000 \:\: \Rightarrow \:\: \\approx {Powerlaw(1000, popt[0], popt[1], popt[2])*time_100[0]/60:.1f}$ minutes'))
display(Latex(f'We measured ${69}$ minutes'))
# Out:
# $N = 1000 \:\: \Rightarrow \:\: \approx 80.9$ minutes
# We measured $69$ minutes

# %% [markdown]
# # 2) Collapse Time VS Number of Particles

# %%
tcolls = np.array([tcoll_100, tcoll_125, tcoll_150, tcoll_175, tcoll_200, tcoll_225, tcoll_250, tcoll_275, tcoll_300]).T/T_collapse

# %%
x_dense = np.linspace(0, 350, 1000)

plt.errorbar(Ns, tcolls[0], tcolls[1], fmt='o', color='blue', ecolor='grey', capsize=4, capthick=2, label='Data')
plt.axhline(1, ls='--', color='red', label='Theoretical value')
plt.ylim(0.9, 1.2)
plt.title('Collapse Time VS Number of Particles', fontsize=20)
plt.xlabel('Number of particles')
plt.ylabel('Collapse time (in units of the theoretical one)')
plt.legend(fontsize=20)
